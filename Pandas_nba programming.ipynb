# %%
import pandas as pd

# %%
df=pd.read_csv("nba.csv")

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
cities=['pune','mumbai','nashik','satara']

# %%
df=pd.DataFrame(cities)
df
# Out:
#         0
# 0    pune
# 1  mumbai
# 2  nashik
# 3  satara

# %%
cities_info=[
    ['pune',9400000,330,18.52,73.85,False],
    ['mumbai',19400000,530,28.52,63.85,True],
    ['nagpur',4000000,230,34.52,43.85,True],
    ['aurangabad',280000,170,32.52,66.85,False]
]

# %%
df=pd.DataFrame(cities_info,
               columns=['city_name','population','area','lat','long','metro'])
df
# Out:
#     city_name  population  area    lat   long  metro
# 0        pune     9400000   330  18.52  73.85  False
# 1      mumbai    19400000   530  28.52  63.85   True
# 2      nagpur     4000000   230  34.52  43.85   True
# 3  aurangabad      280000   170  32.52  66.85  False

# %%
city_dict={
    'city':['mumbai','pune','nagpur','aurangabad'],
    'population':[9400000,22200000,4000000,250000],
    'area':[555,333,222,180]
}

# %%
df=pd.DataFrame(city_dict)
df
# Out:
#          city  population  area
# 0      mumbai     9400000   555
# 1        pune    22200000   333
# 2      nagpur     4000000   222
# 3  aurangabad      250000   180

# %%
df=pd.read_csv('nba.csv')
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
#summary function

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.head().T
# Out:
#                        0               1                  2               3  \
# Name       Avery Bradley     Jae Crowder       John Holland     R.J. Hunter
# Team      Boston Celtics  Boston Celtics     Boston Celtics  Boston Celtics
# Number                 0              99                 30              28
# Position              PG              SF                 SG              SG
# Age                   25              25                 27              22
# Height               6-2             6-6                6-5             6-5
# Weight               180             235                205             185
# College            Texas       Marquette  Boston University   Georgia State
# Salary       7.73034e+06     6.79612e+06                NaN     1.14864e+06
#
#                        4
# Name       Jonas Jerebko
# Team      Boston Celtics
# Number                 8
# Position              PF
# Age                   29
# Height              6-10
# ...

# %%
df.head(15)
# Out:
#                Name            Team  Number Position   Age Height  Weight  \
# 0     Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1       Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2      John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3       R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4     Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5      Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6     Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7      Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8      Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9      Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# 10  Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# 11    Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9   185.0
# ...

# %%
df.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
df.tail(8)
# Out:
#               Name       Team  Number Position   Age Height  Weight   College  \
# 450     Joe Ingles  Utah Jazz     2.0       SF  28.0    6-8   226.0       NaN
# 451  Chris Johnson  Utah Jazz    23.0       SF  26.0    6-6   206.0    Dayton
# 452     Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0  Kentucky
# 453   Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0    Butler
# 454      Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0       NaN
# 455   Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0       NaN
# 456    Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0    Kansas
# 457            NaN        NaN     NaN      NaN   NaN    NaN     NaN       NaN
#
#         Salary
# 450  2050000.0
# 451   981348.0
# 452  2239800.0
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
df.shape
# Out:
# (458, 9)

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# ...

# %%
df.describe(include=['object'])
# Out:
#                  Name                  Team Position Height   College
# count             457                   457      457    457       373
# unique            457                    30        5     18       118
# top     Nick Collison  New Orleans Pelicans       SG    6-9  Kentucky
# freq                1                    19      102     59        22

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['Name']
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df.Name
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
df['Salary']
# Out:
# 0      7730337.0
# 1      6796117.0
# 2            NaN
# 3      1148640.0
# 4      5000000.0
#          ...
# 453    2433333.0
# 454     900000.0
# 455    2900000.0
# 456     947276.0
# 457          NaN
# Name: Salary, Length: 458, dtype: float64

# %%
df[['Name','Salary']]
# Out:
#               Name     Salary
# 0    Avery Bradley  7730337.0
# 1      Jae Crowder  6796117.0
# 2     John Holland        NaN
# 3      R.J. Hunter  1148640.0
# 4    Jonas Jerebko  5000000.0
# ..             ...        ...
# 453   Shelvin Mack  2433333.0
# 454      Raul Neto   900000.0
# 455   Tibor Pleiss  2900000.0
# 456    Jeff Withey   947276.0
# 457            NaN        NaN
#
# [458 rows x 2 columns]

# %%
df[['Name','Salary','Team']]
# Out:
#               Name     Salary            Team
# 0    Avery Bradley  7730337.0  Boston Celtics
# 1      Jae Crowder  6796117.0  Boston Celtics
# 2     John Holland        NaN  Boston Celtics
# 3      R.J. Hunter  1148640.0  Boston Celtics
# 4    Jonas Jerebko  5000000.0  Boston Celtics
# ..             ...        ...             ...
# 453   Shelvin Mack  2433333.0       Utah Jazz
# 454      Raul Neto   900000.0       Utah Jazz
# 455   Tibor Pleiss  2900000.0       Utah Jazz
# 456    Jeff Withey   947276.0       Utah Jazz
# 457            NaN        NaN             NaN
#
# [458 rows x 3 columns]

# %%
#adding a new column into df
df['Game']="basketBall"
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary        Game
# 0              Texas  7730337.0  basketBall
# 1          Marquette  6796117.0  basketBall
# 2  Boston University        NaN  basketBall
# 3      Georgia State  1148640.0  basketBall
# 4                NaN  5000000.0  basketBall

# %%
df['Tax']=df['Salary']*0.1
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary        Game       Tax
# 0              Texas  7730337.0  basketBall  773033.7
# 1          Marquette  6796117.0  basketBall  679611.7
# 2  Boston University        NaN  basketBall       NaN
# 3      Georgia State  1148640.0  basketBall  114864.0
# 4                NaN  5000000.0  basketBall  500000.0

# %%
df['Gross_Salary']=df['Salary']-df['Tax']
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary        Game       Tax  Gross_Salary
# 0              Texas  7730337.0  basketBall  773033.7     6957303.3
# 1          Marquette  6796117.0  basketBall  679611.7     6116505.3
# 2  Boston University        NaN  basketBall       NaN           NaN
# 3      Georgia State  1148640.0  basketBall  114864.0     1033776.0
# 4                NaN  5000000.0  basketBall  500000.0     4500000.0

# %%
#indexing loc,iloc
df.iloc[0]
# Out:
# Name             Avery Bradley
# Team            Boston Celtics
# Number                       0
# Position                    PG
# Age                         25
# Height                     6-2
# Weight                     180
# College                  Texas
# Salary             7.73034e+06
# Game                basketBall
# Tax                     773034
# Gross_Salary        6.9573e+06
# Name: 0, dtype: object

# %%
df.iloc[0:4]
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#              College     Salary        Game       Tax  Gross_Salary
# 0              Texas  7730337.0  basketBall  773033.7     6957303.3
# 1          Marquette  6796117.0  basketBall  679611.7     6116505.3
# 2  Boston University        NaN  basketBall       NaN           NaN
# 3      Georgia State  1148640.0  basketBall  114864.0     1033776.0

# %%
df.iloc[0:4,0:4]
# Out:
#             Name            Team  Number Position
# 0  Avery Bradley  Boston Celtics     0.0       PG
# 1    Jae Crowder  Boston Celtics    99.0       SF
# 2   John Holland  Boston Celtics    30.0       SG
# 3    R.J. Hunter  Boston Celtics    28.0       SG

# %%
df.iloc[0:4,0:6:2]
# Out:
#             Name  Number   Age
# 0  Avery Bradley     0.0  25.0
# 1    Jae Crowder    99.0  25.0
# 2   John Holland    30.0  27.0
# 3    R.J. Hunter    28.0  22.0

# %%
df.iloc[0:10:2,0:8:2]
# Out:
#             Name  Number   Age  Weight
# 0  Avery Bradley     0.0  25.0   180.0
# 2   John Holland    30.0  27.0   205.0
# 4  Jonas Jerebko     8.0  29.0   231.0
# 6  Jordan Mickey    55.0  21.0   235.0
# 8   Terry Rozier    12.0  22.0   190.0

# %%
df.iloc[0:10:2,0:8:2]
# Out:
#             Name  Number   Age  Weight
# 0  Avery Bradley     0.0  25.0   180.0
# 2   John Holland    30.0  27.0   205.0
# 4  Jonas Jerebko     8.0  29.0   231.0
# 6  Jordan Mickey    55.0  21.0   235.0
# 8   Terry Rozier    12.0  22.0   190.0

# %%
df.iloc[0:100]['Name']
# Out:
# 0                Avery Bradley
# 1                  Jae Crowder
# 2                 John Holland
# 3                  R.J. Hunter
# 4                Jonas Jerebko
#                 ...
# 95                  Jeff Green
# 96               Blake Griffin
# 97              Wesley Johnson
# 98              DeAndre Jordan
# 99    Luc Richard Mbah a Moute
# Name: Name, Length: 100, dtype: object

# %%
df.iloc[0:100][['Name','Age','Salary']]
# Out:
#                         Name   Age      Salary
# 0              Avery Bradley  25.0   7730337.0
# 1                Jae Crowder  25.0   6796117.0
# 2               John Holland  27.0         NaN
# 3                R.J. Hunter  22.0   1148640.0
# 4              Jonas Jerebko  29.0   5000000.0
# ..                       ...   ...         ...
# 95                Jeff Green  29.0   9650000.0
# 96             Blake Griffin  27.0  18907726.0
# 97            Wesley Johnson  28.0   1100602.0
# 98            DeAndre Jordan  27.0  19689000.0
# 99  Luc Richard Mbah a Moute  29.0    947276.0
#
# [100 rows x 3 columns]

# %%
#first 10 row and first 10 columns
df.iloc[:10,:10]
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary        Game
# 0              Texas   7730337.0  basketBall
# 1          Marquette   6796117.0  basketBall
# 2  Boston University         NaN  basketBall
# ...

# %%
df.iloc[300:,4:]
# Out:
#       Age Height  Weight           College      Salary        Game        Tax  \
# 300  28.0    6-6   215.0    North Carolina  10000000.0  basketBall  1000000.0
# 301  24.0    6-7   230.0   San Diego State  16407500.0  basketBall  1640750.0
# 302  27.0    7-3   290.0               NaN   1200000.0  basketBall   120000.0
# 303  33.0    6-7   199.0  Western Carolina    200600.0  basketBall    20060.0
# 304  40.0    6-3   200.0              Utah    250750.0  basketBall    25075.0
# ..    ...    ...     ...               ...         ...         ...        ...
# 453  26.0    6-3   203.0            Butler   2433333.0  basketBall   243333.3
# 454  24.0    6-1   179.0               NaN    900000.0  basketBall    90000.0
# 455  26.0    7-3   256.0               NaN   2900000.0  basketBall   290000.0
# 456  26.0    7-0   231.0            Kansas    947276.0  basketBall    94727.6
# 457   NaN    NaN     NaN               NaN         NaN  basketBall        NaN
#
#      Gross_Salary
# ...

# %%
df.iloc[0][4]
# Out:
# 25.0

# %%
df.iloc[0]['Age']
# Out:
# 25.0

# %%
df.iloc[0][4:8]
# Out:
# Age           25
# Height       6-2
# Weight       180
# College    Texas
# Name: 0, dtype: object

# %%
df.iloc[0][['Age','Salary']]
# Out:
# Age                25
# Salary    7.73034e+06
# Name: 0, dtype: object

# %%
df.iloc[0]['Age']
# Out:
# 25.0

# %%
df2 = pd.read_csv('nba.csv',index_col='Name')
df2
# Out:
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder    Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland   Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ...                       ...     ...      ...   ...    ...     ...
# Shelvin Mack        Utah Jazz     8.0       PG  26.0    6-3   203.0
# Raul Neto           Utah Jazz    25.0       PG  24.0    6-1   179.0
# Tibor Pleiss        Utah Jazz    21.0        C  26.0    7-3   256.0
# Jeff Withey         Utah Jazz    24.0        C  26.0    7-0   231.0
# NaN                       NaN     NaN      NaN   NaN    NaN     NaN
#
#                          College     Salary
# Name
# Avery Bradley              Texas  7730337.0
# Jae Crowder            Marquette  6796117.0
# ...

# %%
df2.loc['Avery Bradley']
# Out:
# Team        Boston Celtics
# Number                   0
# Position                PG
# Age                     25
# Height                 6-2
# Weight                 180
# College              Texas
# Salary         7.73034e+06
# Name: Avery Bradley, dtype: object

# %%
df2.loc['Avery Bradley'][3]
# Out:
# 25.0

# %%
df2.loc['Avery Bradley'][3:6]
# Out:
# Age        25
# Height    6-2
# Weight    180
# Name: Avery Bradley, dtype: object

# %%
#Cheacking null value

# %%
df.isnull()
# Out:
#       Name   Team  Number  Position    Age  Height  Weight  College  Salary  \
# 0    False  False   False     False  False   False   False    False   False
# 1    False  False   False     False  False   False   False    False   False
# 2    False  False   False     False  False   False   False    False    True
# 3    False  False   False     False  False   False   False    False   False
# 4    False  False   False     False  False   False   False     True   False
# ..     ...    ...     ...       ...    ...     ...     ...      ...     ...
# 453  False  False   False     False  False   False   False    False   False
# 454  False  False   False     False  False   False   False     True   False
# 455  False  False   False     False  False   False   False     True   False
# 456  False  False   False     False  False   False   False    False   False
# 457   True   True    True      True   True    True    True     True    True
#
#       Game    Tax  Gross_Salary
# ...

# %%
df.isnull().sum()
# Out:
# Name             1
# Team             1
# Number           1
# Position         1
# Age              1
# Height           1
# Weight           1
# College         85
# Salary          12
# Game             0
# Tax             12
# Gross_Salary    12
# dtype: int64

# %%
df.isnull().mean()*10
# Out:
# Name            0.021834
# Team            0.021834
# Number          0.021834
# Position        0.021834
# Age             0.021834
# Height          0.021834
# Weight          0.021834
# College         1.855895
# Salary          0.262009
# Game            0.000000
# Tax             0.262009
# Gross_Salary    0.262009
# dtype: float64

# %%
df.isnull().sum()
# Out:
# Name             1
# Team             1
# Number           1
# Position         1
# Age              1
# Height           1
# Weight           1
# College         85
# Salary          12
# Game             0
# Tax             12
# Gross_Salary    12
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# Name             0.218341
# Team             0.218341
# Number           0.218341
# Position         0.218341
# Age              0.218341
# Height           0.218341
# Weight           0.218341
# College         18.558952
# Salary           2.620087
# Game             0.000000
# Tax              2.620087
# Gross_Salary     2.620087
# dtype: float64

# %%
#series related function

# %%
df['Age'].sum()
# Out:
# 12311.0

# %%
df['Age'].max()
# Out:
# 40.0

# %%
df['Age'].min()
# Out:
# 19.0

# %%
df['Age'].mean()
# Out:
# 26.938730853391686

# %%
df['Age'].std()
# Out:
# 4.4040164244058335

# %%
df['Age'].var()
# Out:
# 19.395360666436343

# %%
df['Age'].median()
# Out:
# 26.0

# %%
df['Age'].mode()
# Out:
# 0    24.0
# dtype: float64

# %%
df['Age'].max()
# Out:
# 40.0

# %%
df['Age'].unique()
# Out:
# array([25., 27., 22., 29., 21., 24., 20., 26., 28., 32., 23., 30., 33.,
#        34., 37., 36., 31., 38., 39., 19., 35., 40., nan])

# %%
df['College'].unique()
# Out:
# array(['Texas', 'Marquette', 'Boston University', 'Georgia State', nan,
#        'LSU', 'Gonzaga', 'Louisville', 'Oklahoma State', 'Ohio State',
#        'Washington', 'Kentucky', 'North Carolina', 'Arizona',
#        'Georgia Tech', 'Cincinnati', 'Miami (FL)', 'Stanford', 'Syracuse',
#        'Saint Louis', 'Kansas', 'Georgetown', 'Texas A&M', 'UCLA', 'UNLV',
#        'Wichita State', "Saint Joseph's", 'Notre Dame', 'Norfolk State',
#        'Duke', 'Murray State', 'Tennessee State', 'Bowling Green',
#        'Purdue', 'Wake Forest', 'Michigan', 'Missouri', 'USC',
#        'Villanova', 'Rider', 'Utah', 'Belmont', 'Davidson', 'Vanderbilt',
#        'Michigan State', 'Florida', 'Washington State', 'Arizona State',
#        'Oklahoma', 'Wyoming', "St. John's", 'Maryland', 'Wisconsin',
#        'Utah Valley', 'North Carolina State', 'UC Santa Barbara',
#        'Baylor', 'Connecticut', 'Oregon State', 'New Mexico', 'Oregon',
# ...

# %%
df['College'].value_counts()
# Out:
# Kentucky            22
# Duke                20
# Kansas              18
# North Carolina      16
# UCLA                15
#                     ..
# Temple               1
# Minnesota            1
# St. Bonaventure      1
# Western Michigan     1
# Long Beach State     1
# Name: College, Length: 118, dtype: int64

# %%
df['Team'].value_counts()
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Washington Wizards        15
# Cleveland Cavaliers       15
# Boston Celtics            15
# Oklahoma City Thunder     15
# Los Angeles Clippers      15
# Los Angeles Lakers        15
# Chicago Bulls             15
# Utah Jazz                 15
# Sacramento Kings          15
# Philadelphia 76ers        15
# Detroit Pistons           15
# Brooklyn Nets             15
# Miami Heat                15
# Toronto Raptors           15
# Houston Rockets           15
# Indiana Pacers            15
# Portland Trail Blazers    15
# Dallas Mavericks          15
# Phoenix Suns              15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Golden State Warriors     15
# Charlotte Hornets         15
# Denver Nuggets            15
# Minnesota Timberwolves    14
# Orlando Magic             14
# Name: Team, dtype: int64

# %%
#Deletion operation

# %%
df.drop(['Game'],axis=1,inplace=True)
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary       Tax  Gross_Salary
# ...

# %%
#iterrating over data in dff

# %%
for i in df:
    print(i)
# Out:
# Name
# Team
# Number
# Position
# Age
# Height
# Weight
# College
# Salary
# Tax
# Gross_Salary

# %%
for i,j in df.itrrows():
    print(i)
    print(j)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-191-cb2580084034> in <module>
# ----> 1 for i,j in df.itrrows():
#       2     print(i)
#       3     print(j)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'itrrows'

# %%
new_player={'name':"akshay",'team':"xyz",'number':55
           'position':'SG','Age':24,'Height':'5-9','Weight':66,
           'College':"Symbiosis",'Salary':123456,'Tax':1234,
           'Gross_salary':343434}
# Out:
#   File "<ipython-input-192-d2bdbc1a6f24>", line 2
#     'position':'SG','Age':24,'Height':'5-9','Weight':66,
#     ^
# SyntaxError: invalid syntax

# %%
new_player
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-193-8f8706af1b2d> in <module>
# ----> 1 new_player
#
# NameError: name 'new_player' is not defined

# %%
new_player_df=pd.DataFrame(new_player,index=[0])
new_player_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-194-34f2a82d7bd3> in <module>
# ----> 1 new_player_df=pd.DataFrame(new_player,index=[0])
#       2 new_player_df
#
# NameError: name 'new_player' is not defined

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary       Tax  Gross_Salary
# ...

# %%
df=pd.concat([new_player_df,df],ignore_index=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-196-80b4f85adf1a> in <module>
# ----> 1 df=pd.concat([new_player_df,df],ignore_index=True)
#       2 df.head()
#
# NameError: name 'new_player_df' is not defined

# %%
df1=pd.DataFrame({'Name':['sachin','shrutoka'],'id':[1,2]})
df1
# Out:
#        Name  id
# 0    sachin   1
# 1  shrutoka   2

# %%
df2=pd.DataFrame({'Name':['Umesh'],'id':[3]})
df2
# Out:
#     Name  id
# 0  Umesh   3

# %%
df1.append(df2,ignore_index=True)
# Out:
#        Name  id
# 0    sachin   1
# 1  shrutoka   2
# 2     Umesh   3

# %%
df1.append(df2,verify_integrity=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-200-687058aeef4c> in <module>
# ----> 1 df1.append(df2,verify_integrity=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7741         else:
#    7742             to_concat = [self, other]
# -> 7743         return concat(
#    7744             to_concat,
#    7745             ignore_index=ignore_index,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     272     ValueError: Indexes have overlapping values: ['a']
#     273     """
# --> 274     op = _Concatenator(
#     275         objs,
#     276         axis=axis,
#
# ...

# %%
df1.append(df2,verify_integrity=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-687058aeef4c> in <module>
# ----> 1 df1.append(df2,verify_integrity=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7741         else:
#    7742             to_concat = [self, other]
# -> 7743         return concat(
#    7744             to_concat,
#    7745             ignore_index=ignore_index,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     272     ValueError: Indexes have overlapping values: ['a']
#     273     """
# --> 274     op = _Concatenator(
#     275         objs,
#     276         axis=axis,
#
# ...

# %%
#filtering

# %%
df[df['Age']>30]
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 19      Jarrett Jack           Brooklyn Nets     2.0       PG  32.0    6-3
# 31      Lou Amundson         New York Knicks    17.0       PF  33.0    6-9
# 33   Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 34     Jose Calderon         New York Knicks     3.0       PG  34.0    6-3
# 43     Sasha Vujacic         New York Knicks    18.0       SG  32.0    6-7
# ..               ...                     ...     ...      ...   ...    ...
# 406  Tayshaun Prince  Minnesota Timberwolves    12.0       SF  36.0    6-9
# 413    Nick Collison   Oklahoma City Thunder     4.0       PF  35.0   6-10
# 415       Randy Foye   Oklahoma City Thunder     6.0       SG  32.0    6-4
# 420    Nazr Mohammed   Oklahoma City Thunder    13.0        C  38.0   6-10
# 434      Chris Kaman  Portland Trail Blazers    35.0        C  34.0    7-0
#
#      Weight           College      Salary        Tax  Gross_Salary
# ...

# %%
df[df['Age']>30]['Name']
# Out:
# 19        Jarrett Jack
# 31        Lou Amundson
# 33     Carmelo Anthony
# 34       Jose Calderon
# 43       Sasha Vujacic
#             ...
# 406    Tayshaun Prince
# 413      Nick Collison
# 415         Randy Foye
# 420      Nazr Mohammed
# 434        Chris Kaman
# Name: Name, Length: 91, dtype: object

# %%
df[df['Age']>30][['Name','Salary']]
# Out:
#                 Name      Salary
# 19      Jarrett Jack   6300000.0
# 31      Lou Amundson   1635476.0
# 33   Carmelo Anthony  22875000.0
# 34     Jose Calderon   7402812.0
# 43     Sasha Vujacic    947276.0
# ..               ...         ...
# 406  Tayshaun Prince    947276.0
# 413    Nick Collison   3750000.0
# 415       Randy Foye   3135000.0
# 420    Nazr Mohammed    222888.0
# 434      Chris Kaman   5016000.0
#
# [91 rows x 2 columns]

# %%
df[(df['Age']>30) & (df['Salary']<1000000)]
# Out:
#                    Name                    Team  Number Position   Age Height  \
# 43        Sasha Vujacic         New York Knicks    18.0       SG  32.0    6-7
# 90     Anderson Varejao   Golden State Warriors    18.0       PF  33.0   6-11
# 102      Pablo Prigioni    Los Angeles Clippers     9.0       PG  39.0    6-3
# 112     Marcelo Huertas      Los Angeles Lakers     9.0       PG  33.0    6-3
# 119   Metta World Peace      Los Angeles Lakers    37.0       SF  36.0    6-7
# 131        Ronnie Price            Phoenix Suns    14.0       PG  32.0    6-2
# 170   Richard Jefferson     Cleveland Cavaliers    24.0       SF  35.0    6-7
# 172         James Jones     Cleveland Cavaliers     1.0       SG  35.0    6-8
# 221         Steve Novak         Milwaukee Bucks     6.0       SF  32.0   6-10
# 240  Charlie Villanueva        Dallas Mavericks     3.0       PF  31.0   6-11
# 256         Jason Terry         Houston Rockets    31.0       SG  38.0    6-2
# ...

# %%
new_df=df[(df['Age']>30) & (df['Salary']<1000000)]

# %%
len(df[(df['Age']>30) & (df['Salary']<1000000)])
# Out:
# 20

# %%
df[(df['Age']>30)  | (df['Salary']<1000000)]
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 16      Markel Brown           Brooklyn Nets    22.0       SG  24.0    6-3
# 19      Jarrett Jack           Brooklyn Nets     2.0       PG  32.0    6-3
# 21   Sean Kilpatrick           Brooklyn Nets     6.0       SG  26.0    6-4
# 25       Willie Reed           Brooklyn Nets    33.0       PF  26.0   6-10
# 26   Thomas Robinson           Brooklyn Nets    41.0       PF  25.0   6-10
# ..               ...                     ...     ...      ...   ...    ...
# 434      Chris Kaman  Portland Trail Blazers    35.0        C  34.0    7-0
# 438     Luis Montero  Portland Trail Blazers    44.0       SG  23.0    6-7
# 451    Chris Johnson               Utah Jazz    23.0       SF  26.0    6-6
# 454        Raul Neto               Utah Jazz    25.0       PG  24.0    6-1
# 456      Jeff Withey               Utah Jazz    24.0        C  26.0    7-0
#
#      Weight           College     Salary       Tax  Gross_Salary
# ...
